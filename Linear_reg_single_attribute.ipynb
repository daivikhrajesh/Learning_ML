# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df.head(5)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
# %matplotlib inline
plt.scatter(df['year'], df['per capita income (US$)'],color='red',marker='+')
plt.xlabel('Year')
plt.ylabel('Per capita income($)')
# Out:
# Text(0, 0.5, 'Per capita income($)')

# %%
reg = linear_model.LinearRegression()

# %%
df.rename(columns={'per capita income (US$)': 'income'}, inplace=True)

# %%
reg.fit(df[['year']],df['income'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# F:\Softwares\Anaconda\Conda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
# %matplotlib inline
plt.scatter(df['year'], df['income'],color='red',marker='+')
plt.xlabel('Year')
plt.ylabel('Per capita income($)')
plt.plot(df['year'], reg.predict(df[['year']]), color='blue', label='Linear Regression Line')

# %%
import joblib

# %%
joblib.dump(reg,'model_lib')
# Out:
# ['model_lib']

# %%
mj = joblib.load('model_lib')

# %%
mj.predict([[2020]])
# Out:
# F:\Softwares\Anaconda\Conda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
